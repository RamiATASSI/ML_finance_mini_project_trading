# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import yfinance as yf
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.tree import plot_tree

# %%
etf_names = ["TAN", "LIT", "KARS", "XOP", "HAIL", "IXC", "FAN", "PICK", "FCG", "TSLA"]
file_names = [f"Data/{ticker}.csv" for ticker in etf_names]
columns_to_drop = ["High", "Low", "Dividends", "Volume", "Stock Splits", "Capital Gains"]
cols = [f"Return_{ticker}" for ticker in etf_names if ticker != "TSLA"]
cols_2 = [f"Rolling_Mean_{ticker}" for ticker in etf_names if ticker != "TSLA"]

# %%
start_date = "2020-01-01"
end_date = datetime.now().strftime("%Y-%m-%d")

for symbol in etf_names:
    stock = yf.Ticker(symbol)
    
    historical_data = stock.history(start=start_date, end=end_date)
    
    filename = f"Data/{symbol}.csv"
    historical_data.to_csv(filename)

# %%
dfs = []
window_size = 5
for file_name, etf_name in zip(file_names, etf_names):
    df = pd.read_csv(file_name).drop(columns = columns_to_drop, errors='ignore')
    df["Return"] = (df["Close"] - df["Open"])/df["Open"] * 100
    df['Rolling_Mean'] = df['Return'].rolling(window=window_size).mean()
    df.rename(columns={'Open': 'Open_' + etf_name, 'Close': 'Close_' + etf_name, 'Return': 'Return_' + etf_name, "Rolling_Mean": "Rolling_Mean_" + etf_name}, inplace=True)
    dfs.append(df)

etfs = dfs[0]
for df, etf_name in zip(dfs[1:-1], etf_names[1:-1]):
    etfs = pd.merge(etfs, df, on="Date", how="outer", suffixes=('', '_' + etf_name))
    
tsla = dfs[-1]

# %%
etfs
# Out:
#                            Date   Open_TAN  Close_TAN  Return_TAN  \
# 0     2020-01-02 00:00:00-05:00  31.290924  31.879812    1.881978
# 1     2020-01-03 00:00:00-05:00  31.620303  31.670208    0.157826
# 2     2020-01-06 00:00:00-05:00  31.270961  31.390736    0.383022
# 3     2020-01-07 00:00:00-05:00  31.380755  31.670208    0.922389
# 4     2020-01-08 00:00:00-05:00  31.670204  32.009563    1.071542
# ...                         ...        ...        ...         ...
# 1077  2024-04-15 00:00:00-04:00  41.750000  40.599998   -2.754495
# 1078  2024-04-16 00:00:00-04:00  40.110001  39.740002   -0.922461
# 1079  2024-04-17 00:00:00-04:00  40.099998  40.099998    0.000000
# 1080  2024-04-18 00:00:00-04:00  40.220001  39.700001   -1.292890
# 1081  2024-04-19 00:00:00-04:00  39.560001  39.590000    0.075831
#
#       Rolling_Mean_TAN   Open_LIT  Close_LIT  Return_LIT  Rolling_Mean_LIT  \
# 0                  NaN  26.907331  26.907331    0.000000               NaN
# 1                  NaN  26.557630  26.538202   -0.073155               NaN
# 2                  NaN  26.324503  26.654774    1.254613               NaN
# 3                  NaN  26.839332  27.014181    0.651467               NaN
# 4             0.883351  26.343928  26.450779    0.405600          0.447705
# ...                ...        ...        ...         ...               ...
# 1077         -0.700844  44.669998  44.029999   -1.432728         -0.644862
# 1078         -1.524647  42.860001  42.740002   -0.279979         -0.839027
# 1079         -1.606858  43.189999  43.150002   -0.092607         -0.813494
# 1080         -1.576627  43.209999  42.910000   -0.694282         -0.926206
# 1081         -0.978803  42.320000  42.419998    0.236291         -0.452661
#
#       Open_KARS  ...  Return_FAN  Rolling_Mean_FAN  Open_PICK  Close_PICK  \
# 0     22.005930  ...   -0.407889               NaN  24.834176   24.727026
# 1     21.905113  ...   -0.548320               NaN  24.520969   24.339638
# 2     21.877616  ...    0.138125               NaN  24.084124   24.216002
# 3     22.005930  ...   -0.483090               NaN  24.092362   24.257210
# 4     22.235063  ...    0.139369         -0.232361  24.174789   24.487997
# ...         ...  ...         ...               ...        ...         ...
# 1077  21.719999  ...   -1.840892         -0.682141  43.680000   43.049999
# 1078  20.969999  ...   -0.469797         -0.814660  42.720001   42.459999
# 1079  21.200001  ...    0.000000         -0.762373  43.279999   42.799999
# 1080  21.360001  ...    0.134045         -0.696425  42.919998   42.869999
# 1081  21.139999  ...    0.000000         -0.435329  42.700001   42.779999
#
#       Return_PICK  Rolling_Mean_PICK   Open_FCG  Close_FCG  Return_FCG  \
# 0       -0.431461                NaN  10.634084  10.380892   -2.380952
# 1       -0.739493                NaN  10.695201  10.599163   -0.897956
# 2        0.547570                NaN  10.712665  10.703934   -0.081501
# 3        0.684231                NaN  10.712660  10.878545    1.548489
# 4        1.295599           0.271289  10.843624  10.450739   -3.623187
# ...           ...                ...        ...        ...         ...
# 1077    -1.442310          -0.749422  27.920000  27.469999   -1.611751
# 1078    -0.608619          -0.985197  27.280001  27.250000   -0.109973
# 1079    -1.109056          -1.165715  27.200001  27.049999   -0.551476
# 1080    -0.116494          -1.111084  27.190001  26.980000   -0.772346
# 1081     0.187349          -0.617826  26.910000  27.280001    1.374957
#
#       Rolling_Mean_FCG
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4            -1.087022
# ...                ...
# 1077         -0.588179
# 1078         -0.631450
# 1079         -0.941318
# 1080         -0.940913
# 1081         -0.334118
#
# [1082 rows x 37 columns]

# %%
tsla
# Out:
#                            Date   Open_TSLA  Close_TSLA  Return_TSLA
# 0     2020-01-02 00:00:00-05:00   28.299999   28.684000     1.356893
# 1     2020-01-03 00:00:00-05:00   29.366667   29.534000     0.569808
# 2     2020-01-06 00:00:00-05:00   29.364668   30.102667     2.513221
# 3     2020-01-07 00:00:00-05:00   30.760000   31.270666     1.660162
# 4     2020-01-08 00:00:00-05:00   31.580000   32.809334     3.892761
# ...                         ...         ...         ...          ...
# 1077  2024-04-15 00:00:00-04:00  170.240005  161.479996    -5.145682
# 1078  2024-04-16 00:00:00-04:00  156.740005  157.110001     0.236057
# 1079  2024-04-17 00:00:00-04:00  157.639999  155.449997    -1.389243
# 1080  2024-04-18 00:00:00-04:00  151.250000  149.929993    -0.872732
# 1081  2024-04-19 00:00:00-04:00  148.970001  147.050003    -1.288849
#
# [1082 rows x 4 columns]

# %%
selected_df = etfs[cols].copy()
selected_df["Return_TSLA"] = tsla["Return_TSLA"].copy()

correlation_matrix = selected_df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='Reds', fmt=".2f", linewidths=0.5)
plt.title('Correlation of Returns')
plt.show()

# %% [markdown]
# ## Logistic Regression Based on Yesterday's return

# %%
X_classification = etfs[cols]
y_classification = [(1 if return_val > 0 else 0) for return_val in tsla['Return_TSLA']]

y_classification = y_classification[1:]
X_classification = X_classification[:-1]

len(y_classification), len(X_classification)
# Out:
# (1081, 1081)

# %%
X_train, X_test, y_train_classification, y_test_classification = train_test_split(X_classification, y_classification, test_size=0.2, random_state=42)

classifier = LogisticRegression()
classifier.fit(X_train, y_train_classification)
# Out:
# LogisticRegression()

# %%
y_pred_classification = classifier.predict(X_test)
classification_accuracy = accuracy_score(y_test_classification, y_pred_classification)
print("Classification Accuracy:", classification_accuracy)
# Out:
# Classification Accuracy: 0.5576036866359447

# %% [markdown]
# ## Random Tree Model Based on Yesterday's return

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, max_depth=3, random_state=42)
rf_classifier.fit(X_train, y_train_classification)


plt.figure(figsize=(20, 10))
plot_tree(rf_classifier.estimators_[0], feature_names=X_train.columns, class_names=['Negative', 'Positive'], filled=True)
plt.title('Random Forest Decision Tree')
plt.show()

# %%
y_pred_classification = rf_classifier.predict(X_test)


randomtree_accuracy = accuracy_score(y_test_classification, y_pred_classification)
print("RandomTree Accuracy:", randomtree_accuracy)
# Out:
# RandomTree Accuracy: 0.5483870967741935

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Create a Sequential model
model = Sequential()

# Add input layer and hidden layers
model.add(Dense(units=64, activation='relu', input_shape=(X_train.shape[1],)))  # Assuming X_train.shape[1] is the number of features
model.add(Dense(units=32, activation='relu'))

# Add output layer
model.add(Dense(units=1, activation='sigmoid'))  # Assuming binary classification

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, np.array(y_train_classification), epochs=10, batch_size=32, validation_split=0.2)  # Assuming 10 epochs and batch size of 32

# Evaluate the model
loss, accuracy = model.evaluate(X_test, np.array(y_test_classification))
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# Epoch 1/10
# /opt/homebrew/lib/python3.11/site-packages/keras/src/layers/core/dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5318 - loss: 0.6969 - val_accuracy: 0.6185 - val_loss: 0.6646
# Epoch 2/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - accuracy: 0.5831 - loss: 0.6774 - val_accuracy: 0.6590 - val_loss: 0.6493
# Epoch 3/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - accuracy: 0.5976 - loss: 0.6667 - val_accuracy: 0.6474 - val_loss: 0.6458
# Epoch 4/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step - accuracy: 0.5917 - loss: 0.6631 - val_accuracy: 0.6532 - val_loss: 0.6437
# Epoch 5/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - accuracy: 0.6127 - loss: 0.6538 - val_accuracy: 0.6358 - val_loss: 0.6375
# Epoch 6/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - accuracy: 0.5930 - loss: 0.6571 - val_accuracy: 0.6358 - val_loss: 0.6411
# Epoch 7/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - accuracy: 0.6001 - loss: 0.6547 - val_accuracy: 0.6358 - val_loss: 0.6385
# Epoch 8/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - accuracy: 0.6247 - loss: 0.6498 - val_accuracy: 0.6358 - val_loss: 0.6374
# Epoch 9/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - accuracy: 0.6005 - loss: 0.6495 - val_accuracy: 0.6416 - val_loss: 0.6344
# Epoch 10/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - accuracy: 0.6188 - loss: 0.6510 - val_accuracy: 0.6474 - val_loss: 0.6371
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - accuracy: 0.5441 - loss: 0.6992
# Test Loss: 0.6894465684890747
# Test Accuracy: 0.5648148059844971

# %% [markdown]
# ## Logistic Regression Based on 5 days rolling window

# %%
X_classification = etfs[cols_2]
y_classification = [(1 if return_val > 0 else 0) for return_val in tsla['Return_TSLA']]

y_classification = y_classification[4:]
X_classification = X_classification[4:]

len(y_classification), len(X_classification)
# Out:
# (1078, 1078)

# %%
X_train, X_test, y_train_classification, y_test_classification = train_test_split(X_classification, y_classification, test_size=0.2, random_state=42)

classifier = LogisticRegression()
classifier.fit(X_train, y_train_classification)
# Out:
# LogisticRegression()

# %%
y_pred_classification = classifier.predict(X_test)
classification_accuracy = accuracy_score(y_test_classification, y_pred_classification)
print("Classification Accuracy:", classification_accuracy)
# Out:
# Classification Accuracy: 0.5416666666666666

# %% [markdown]
# ## Random Tree Model Based on 5 days rolling window

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, max_depth=3, random_state=42)
rf_classifier.fit(X_train, y_train_classification)


plt.figure(figsize=(20, 10))
plot_tree(rf_classifier.estimators_[0], feature_names=X_train.columns, class_names=['Negative', 'Positive'], filled=True)
plt.title('Random Forest Decision Tree')
plt.show()

# %%
y_pred_classification = rf_classifier.predict(X_test)


randomtree_accuracy = accuracy_score(y_test_classification, y_pred_classification)
print("RandomTree Accuracy:", randomtree_accuracy)
# Out:
# RandomTree Accuracy: 0.5833333333333334

# %% [markdown]
# ## Neural Networks

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Create a Sequential model
model = Sequential()

# Add input layer and hidden layers
model.add(Dense(units=64, activation='relu', input_shape=(X_train.shape[1],)))  # Assuming X_train.shape[1] is the number of features
model.add(Dense(units=32, activation='relu'))

# Add output layer
model.add(Dense(units=1, activation='sigmoid'))  # Assuming binary classification

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, np.array(y_train_classification), epochs=10, batch_size=32, validation_split=0.2)  # Assuming 10 epochs and batch size of 32

# Evaluate the model
loss, accuracy = model.evaluate(X_test, np.array(y_test_classification))
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# Epoch 1/10
# /opt/homebrew/lib/python3.11/site-packages/keras/src/layers/core/dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5295 - loss: 0.6951 - val_accuracy: 0.6474 - val_loss: 0.6568
# Epoch 2/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - accuracy: 0.6153 - loss: 0.6684 - val_accuracy: 0.6416 - val_loss: 0.6446
# Epoch 3/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.5933 - loss: 0.6660 - val_accuracy: 0.6474 - val_loss: 0.6418
# Epoch 4/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step - accuracy: 0.6002 - loss: 0.6606 - val_accuracy: 0.6416 - val_loss: 0.6416
# Epoch 5/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - accuracy: 0.6190 - loss: 0.6562 - val_accuracy: 0.6647 - val_loss: 0.6429
# Epoch 6/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - accuracy: 0.6135 - loss: 0.6590 - val_accuracy: 0.6705 - val_loss: 0.6411
# Epoch 7/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - accuracy: 0.6037 - loss: 0.6622 - val_accuracy: 0.6416 - val_loss: 0.6408
# Epoch 8/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - accuracy: 0.6036 - loss: 0.6614 - val_accuracy: 0.6416 - val_loss: 0.6336
# Epoch 9/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - accuracy: 0.5841 - loss: 0.6626 - val_accuracy: 0.6474 - val_loss: 0.6416
# Epoch 10/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - accuracy: 0.5991 - loss: 0.6528 - val_accuracy: 0.6590 - val_loss: 0.6405
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step - accuracy: 0.5636 - loss: 0.7007
# Test Loss: 0.6881675720214844
# Test Accuracy: 0.5787037014961243
